# %%
using Sunny, GLMakie, ColorSchemes, Colors, LinearAlgebra, ProgressMeter
include("Frida_code/func_clino1.jl")
units = Units(:meV, :angstrom)
# Out:
# Units(:meV, :angstrom)

# %%
cif = joinpath(@__DIR__, "Ho2Ti2O7_mp-33948_symmetrized.cif")
crystal = Crystal(cif; symprec=0.001)
Ho_sub = subcrystal(crystal, "Ho0")
# Out:
# Crystal
# Spacegroup 'F d -3 m' (227)
# Lattice params a=10.15, b=10.15, c=10.15, α=90°, β=90°, γ=90°
# Cell volume 1045
# Type 'Ho0', Wyckoff 16d (site sym. '.-3m'):
#    1. [5/8, 1/8, 1/8]
#    2. [7/8, 3/8, 1/8]
#    3. [1/8, 5/8, 1/8]
#    4. [3/8, 7/8, 1/8]
#    5. [7/8, 1/8, 3/8]
#    6. [5/8, 3/8, 3/8]
#    7. [3/8, 5/8, 3/8]
#    8. [1/8, 7/8, 3/8]
#    9. [1/8, 1/8, 5/8]
#    10. [3/8, 3/8, 5/8]
#    11. [5/8, 5/8, 5/8]
#    12. [7/8, 7/8, 5/8]
#    13. [3/8, 1/8, 7/8]
#    14. [1/8, 3/8, 7/8]
#    15. [7/8, 5/8, 7/8]
#    16. [5/8, 7/8, 7/8]

# %%
dims = (3, 3, 3)  # Supercell dimensions
momentinfo = [1 => Moment(s=8, g=2)]  # Specify local moment information, note that all sites are symmetry equivalent
#sys_pyro = System(crystal, momentinfo, :dipole; dims)    # Make a system in dipole (Landau-Lifshitz) mode on pyrochlore lattice
sys_Ho = System(Ho_sub, momentinfo, :dipole; dims); # Same on MgCr2O4 crystal

# %%
print_symmetry_table(crystal, 5.9)
# Out:
# Atom 1
# Type 'Ho0', position [5/8, 1/8, 1/8], Wyckoff 16d
# Allowed g-tensor: [A B B
#                    B A B
#                    B B A]
# Allowed anisotropy in Stevens operators:
#     c₁*(𝒪[2,-2]+2𝒪[2,-1]+2𝒪[2,1]) +
#     c₂*(7𝒪[4,-3]+2𝒪[4,-2]-𝒪[4,-1]-𝒪[4,1]-7𝒪[4,3]) + c₃*(𝒪[4,0]+5𝒪[4,4]) +
#     c₄*(11𝒪[6,-6]+8𝒪[6,-3]-𝒪[6,-2]+8𝒪[6,-1]+8𝒪[6,1]-8𝒪[6,3]) + c₅*(-𝒪[6,0]+21𝒪[6,4]) + c₆*(9𝒪[6,-6]+24𝒪[6,-5]+5𝒪[6,-2]+8𝒪[6,-1]+8𝒪[6,1]+24𝒪[6,5])
#
# Atom 17
# Type 'Ti1', position [1/8, 1/8, 1/8], Wyckoff 16c
# Allowed g-tensor: [A B B
#                    B A B
#                    B B A]
# Allowed anisotropy in Stevens operators:
#     c₁*(𝒪[2,-2]+2𝒪[2,-1]+2𝒪[2,1]) +
#     c₂*(7𝒪[4,-3]+2𝒪[4,-2]-𝒪[4,-1]-𝒪[4,1]-7𝒪[4,3]) + c₃*(𝒪[4,0]+5𝒪[4,4]) +
#     c₄*(11𝒪[6,-6]+8𝒪[6,-3]-𝒪[6,-2]+8𝒪[6,-1]+8𝒪[6,1]-8𝒪[6,3]) + c₅*(-𝒪[6,0]+21𝒪[6,4]) + c₆*(9𝒪[6,-6]+24𝒪[6,-5]+5𝒪[6,-2]+8𝒪[6,-1]+8𝒪[6,1]+24𝒪[6,5])
#
# Atom 33
# Type 'O2', position [0.2058, 0, 0], Wyckoff 48f
# Allowed g-tensor: [A 0 0
#                    0 B C
#                    0 C B]
# Allowed anisotropy in Stevens operators:
#     c₁*𝒪[2,-1] + c₂*(-𝒪[2,0]+3𝒪[2,2]) +
#     c₃*(7𝒪[4,-3]-𝒪[4,-1]) + c₄*(𝒪[4,0]+5𝒪[4,2]) + c₅*(𝒪[4,0]+5𝒪[4,4]) +
#     c₆*(3𝒪[6,-5]-𝒪[6,-3]) + c₇*(3𝒪[6,-5]+𝒪[6,-1]) + c₈*(-𝒪[6,0]+21𝒪[6,4]) + c₉*(-(16/231)𝒪[6,0]+(5/11)𝒪[6,2]+𝒪[6,6])
#
# Atom 81
# Type 'O3', position [1/2, 0, 0], Wyckoff 8b
# Allowed g-tensor: [A 0 0
#                    0 A 0
#                    0 0 A]
# Allowed anisotropy in Stevens operators:
#     c₁*(𝒪[4,0]+5𝒪[4,4]) +
#     c₂*(-𝒪[6,0]+21𝒪[6,4])
#
# Bond(17, 33, [0, 0, 0])
# Distance 1.972320864, coordination 6 (from atom 17) and 2 (from atom 33)
# Connects 'Ti1' at [1/8, 1/8, 1/8] to 'O2' at [0.2058, 0, 0]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(1, 81, [0, 0, 0])
# Distance 2.196932378, coordination 2 (from atom 1) and 4 (from atom 81)
# Connects 'Ho0' at [5/8, 1/8, 1/8] to 'O3' at [1/2, 0, 0]
# Allowed exchange matrix: [A B B
#                           B A B
#                           B B A]
#
# Bond(1, 34, [0, 0, 0])
# Distance 2.482967119, coordination 6 (from atom 1) and 2 (from atom 34)
# Connects 'Ho0' at [5/8, 1/8, 1/8] to 'O2' at [0.7942, 0, 0]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(33, 41, [0, 0, 0])
# Distance 2.614861511, coordination 4
# Connects 'O2' at [0.2058, 0, 0] to 'O2' at [1/4, 1/4, 0.04419]
# Allowed exchange matrix: [  A C+E D-F
#                           C-E   B C+E
#                           D+F C-E   A]
# Allowed DM vector: [E F E]
#
# Bond(33, 35, [0, 0, 0])
# Distance 2.953421346, coordination 4
# Connects 'O2' at [0.2058, 0, 0] to 'O2' at [0, 0.2058, 0]
# Allowed exchange matrix: [  A D+F C-E
#                           D-F   A C+E
#                           C+E C-E   B]
# Allowed DM vector: [E E F]
#
# Bond(33, 81, [0, 0, 0])
# Distance 2.985213738, coordination 1 (from atom 33) and 6 (from atom 81)
# Connects 'O2' at [0.2058, 0, 0] to 'O3' at [1/2, 0, 0]
# Allowed exchange matrix: [A 0 0
#                           0 B C
#                           0 C B]
#
# Bond(1, 2, [0, 0, 0])
# Distance 3.587575551, coordination 6
# Connects 'Ho0' at [5/8, 1/8, 1/8] to 'Ho0' at [7/8, 3/8, 1/8]
# Allowed exchange matrix: [ A  C D
#                            C  A D
#                           -D -D B]
# Allowed DM vector: [D -D 0]
#
# Bond(1, 18, [0, 0, 0])
# Distance 3.587575551, coordination 6
# Connects 'Ho0' at [5/8, 1/8, 1/8] to 'Ti1' at [3/8, 3/8, 1/8]
# Allowed exchange matrix: [  A   D C+E
#                             D   A C+E
#                           C-E C-E   B]
# Allowed DM vector: [E -E 0]
#
# Bond(17, 18, [0, 0, 0])
# Distance 3.587575551, coordination 6
# Connects 'Ti1' at [1/8, 1/8, 1/8] to 'Ti1' at [3/8, 3/8, 1/8]
# Allowed exchange matrix: [ A  C D
#                            C  A D
#                           -D -D B]
# Allowed DM vector: [D -D 0]
#
# Bond(34, 83, [0, 0, 0])
# Distance 3.615490853, coordination 2 (from atom 34) and 12 (from atom 83)
# Connects 'O2' at [0.7942, 0, 0] to 'O3' at [3/4, 1/4, 1/4]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(19, 36, [0, 0, 0])
# Distance 3.806004704, coordination 6 (from atom 19) and 2 (from atom 36)
# Connects 'Ti1' at [5/8, 5/8, 1/8] to 'O2' at [1/2, 0.2942, 0]
# Allowed exchange matrix: [  A C-E   D
#                           C+E   B C+E
#                             D C-E   A]
# Allowed DM vector: [E 0 -E]
#
# Bond(33, 46, [0, 0, 0])
# Distance 3.944641729, coordination 2
# Connects 'O2' at [0.2058, 0, 0] to 'O2' at [0.04419, 1/4, 1/4]
# Allowed exchange matrix: [A D D
#                           D B C
#                           D C B]
#
# Bond(2, 34, [0, 0, 0])
# Distance 4.093989243, coordination 12 (from atom 2) and 4 (from atom 34)
# Connects 'Ho0' at [7/8, 3/8, 1/8] to 'O2' at [0.7942, 0, 0]
# Allowed exchange matrix: [  A F+I E-H
#                           F-I   B D+G
#                           E+H D-G   C]
# Allowed DM vector: [G H I]
#
# Bond(33, 34, [-1, 0, 0])
# Distance 4.176768523, coordination 1
# Connects 'O2' at [0.2058, 0, 0] to 'O2' at [-0.2058, 0, 0]
# Allowed exchange matrix: [A 0 0
#                           0 B 0
#                           0 0 B]
#
# Bond(17, 81, [0, 0, 0])
# Distance 4.206805226, coordination 6 (from atom 17) and 12 (from atom 81)
# Connects 'Ti1' at [1/8, 1/8, 1/8] to 'O3' at [1/2, 0, 0]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(33, 36, [0, 0, 0])
# Distance 4.221729755, coordination 4
# Connects 'O2' at [0.2058, 0, 0] to 'O2' at [1/2, 0.2942, 0]
# Allowed exchange matrix: [   A D+F -C+E
#                            D-F   A  C+E
#                           -C-E C-E    B]
# Allowed DM vector: [E -E F]
#
# Bond(18, 33, [0, 0, 0])
# Distance 4.363006308, coordination 12 (from atom 18) and 4 (from atom 33)
# Connects 'Ti1' at [3/8, 3/8, 1/8] to 'O2' at [0.2058, 0, 0]
# Allowed exchange matrix: [  A F+I E-H
#                           F-I   B D+G
#                           E+H D-G   C]
# Allowed DM vector: [G H I]
#
# Bond(33, 47, [0, 0, 0])
# Distance 4.393864757, coordination 4
# Connects 'O2' at [0.2058, 0, 0] to 'O2' at [0.4558, 1/4, 1/4]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(81, 83, [0, 0, 0])
# Distance 4.393864757, coordination 4
# Connects 'O3' at [1/2, 0, 0] to 'O3' at [3/4, 1/4, 1/4]
# Allowed exchange matrix: [A B B
#                           B A B
#                           B B A]
#
# Bond(1, 33, [0, 0, 0])
# Distance 4.616373053, coordination 6 (from atom 1) and 2 (from atom 33)
# Connects 'Ho0' at [5/8, 1/8, 1/8] to 'O2' at [0.2058, 0, 0]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(34, 47, [0, 0, 0])
# Distance 4.965934237, coordination 2
# Connects 'O2' at [0.7942, 0, 0] to 'O2' at [0.4558, 1/4, 1/4]
# Allowed exchange matrix: [A D D
#                           D B C
#                           D C B]
#
# Bond(1, 17, [0, 0, 0])
# Distance 5.073598000, coordination 6
# Connects 'Ho0' at [5/8, 1/8, 1/8] to 'Ti1' at [1/8, 1/8, 1/8]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(33, 37, [0, 0, 0])
# Distance 5.152251913, coordination 4
# Connects 'O2' at [0.2058, 0, 0] to 'O2' at [0.2942, 1/2, 0]
# Allowed exchange matrix: [A  D -F
#                           D  B  E
#                           F -E  C]
# Allowed DM vector: [E F 0]
#
# Bond(1, 37, [0, 0, 0])
# Distance 5.230331743, coordination 12 (from atom 1) and 4 (from atom 37)
# Connects 'Ho0' at [5/8, 1/8, 1/8] to 'O2' at [0.2942, 1/2, 0]
# Allowed exchange matrix: [  A F+I E-H
#                           F-I   B D+G
#                           E+H D-G   C]
# Allowed DM vector: [G H I]
#
# Bond(36, 42, [0, 0, 0])
# Distance 5.294218086, coordination 8
# Connects 'O2' at [1/2, 0.2942, 0] to 'O2' at [3/4, 3/4, 0.04419]
# Allowed exchange matrix: [  A F+I E-H
#                           F-I   B D+G
#                           E+H D-G   C]
# Allowed DM vector: [G H I]
#
# Bond(22, 33, [0, 0, 0])
# Distance 5.443477405, coordination 6 (from atom 22) and 2 (from atom 33)
# Connects 'Ti1' at [1/8, 3/8, 3/8] to 'O2' at [0.2058, 0, 0]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(33, 82, [0, 0, 0])
# Distance 5.486596895, coordination 4 (from atom 33) and 24 (from atom 82)
# Connects 'O2' at [0.2058, 0, 0] to 'O3' at [0, 1/2, 0]
# Allowed exchange matrix: [  A F+I E-H
#                           F-I   B D+G
#                           E+H D-G   C]
# Allowed DM vector: [G H I]
#
# Bond(2, 81, [0, 0, 0])
# Distance 5.528825241, coordination 6 (from atom 2) and 12 (from atom 81)
# Connects 'Ho0' at [7/8, 3/8, 1/8] to 'O3' at [1/2, 0, 0]
# Allowed exchange matrix: [  A   D C+E
#                             D   A C+E
#                           C-E C-E   B]
# Allowed DM vector: [E -E 0]
#
# Bond(6, 34, [0, 0, 0])
# Distance 5.648585874, coordination 6 (from atom 6) and 2 (from atom 34)
# Connects 'Ho0' at [5/8, 3/8, 3/8] to 'O2' at [0.7942, 0, 0]
# Allowed exchange matrix: [  A D-E D-E
#                           D+E   B   C
#                           D+E   C   B]
# Allowed DM vector: [0 E -E]
#
# Bond(18, 34, [0, 0, 0])
# Distance 5.846503100, coordination 12 (from atom 18) and 4 (from atom 34)
# Connects 'Ti1' at [3/8, 3/8, 1/8] to 'O2' at [0.7942, 0, 0]
# Allowed exchange matrix: [  A F+I E-H
#                           F-I   B D+G
#                           E+H D-G   C]
# Allowed DM vector: [G H I]
#
# Bond(36, 84, [0, 0, 0])
# Distance 5.853462098, coordination 2 (from atom 36) and 12 (from atom 84)
# Connects 'O2' at [1/2, 0.2942, 0] to 'O3' at [1/4, 3/4, 1/4]
# Allowed exchange matrix: [   A -C+E   D
#                           -C-E    B C+E
#                              D  C-E   A]
# Allowed DM vector: [E 0 E]

# %%
print_symmetry_table(Ho_sub, 5.9)
# Out:
# Atom 1
# Type 'Ho0', position [5/8, 1/8, 1/8], Wyckoff 16d
# Allowed g-tensor: [A B B
#                    B A B
#                    B B A]
# Allowed anisotropy in Stevens operators:
#     c₁*(𝒪[2,-2]+2𝒪[2,-1]+2𝒪[2,1]) +
#     c₂*(7𝒪[4,-3]+2𝒪[4,-2]-𝒪[4,-1]-𝒪[4,1]-7𝒪[4,3]) + c₃*(𝒪[4,0]+5𝒪[4,4]) +
#     c₄*(11𝒪[6,-6]+8𝒪[6,-3]-𝒪[6,-2]+8𝒪[6,-1]+8𝒪[6,1]-8𝒪[6,3]) + c₅*(-𝒪[6,0]+21𝒪[6,4]) + c₆*(9𝒪[6,-6]+24𝒪[6,-5]+5𝒪[6,-2]+8𝒪[6,-1]+8𝒪[6,1]+24𝒪[6,5])
#
# Bond(1, 2, [0, 0, 0])
# Distance 3.587575551, coordination 6
# Connects 'Ho0' at [5/8, 1/8, 1/8] to 'Ho0' at [7/8, 3/8, 1/8]
# Allowed exchange matrix: [ A  C D
#                            C  A D
#                           -D -D B]
# Allowed DM vector: [D -D 0]

# %%
#view_crystal(crystal)

# %%
J = 0.52 /11.604 #0.52/ 11.604 # (meV)
set_exchange!(sys_Ho, J, Bond(1, 3, [0, 0, 0]))

# S = spin_matrices(8)
# O = stevens_matrices(spin_label(sys_Ho, 1))

# D = 2.35 /11.604
# set_onsite_coupling!(sys_Ho, -D *(-O[2,-2]-2*O[2,-1]+2*O[2,1]), 1) 

enable_dipole_dipole!(sys_Ho, units.vacuum_permeability*100)

# sys_extend = reshape_supercell(sys_lr, [10 0 0; 0 10 0; 0 0 10])
# randomize_spins!(sys_extend)
# minimize_energy!(sys_extend, maxiters=10000)

view_crystal(sys_Ho)

# %%
randomize_spins!(sys_Ho)
minimize_energy!(sys_Ho)
plot_spins(sys_Ho; color=[S[3] for S in sys_Ho.dipoles])

# %%
view_crystal(sys_Ho)

# %% [markdown]
# ## Langevin

# %%
kT      = 1.7 / 11            
tol     = 1e-3                 
nsteps  = 1000

dt      = 0.001785
damping = 0.1     
kT      = 1.7/11


sys_i = reshape_supercell(sys_Ho, [10 0 0; 0 10 0; 0 0 10]) 
randomize_spins!(sys_i)

fig2 = Figure(size=(1000, 500))

langevin = Langevin(dt; damping, kT)
suggest_timestep(sys_i, langevin; tol=tol)

energies = [energy_per_site(sys_i)]
for _ in 1:nsteps
    step!(sys_i, langevin)
    push!(energies, energy_per_site(sys_i))
end
ax = Axis(fig2[1,1];
    xlabel = "Timesteps",
    ylabel = "Energy (meV)",
    title  = "dt = $(dt), damping = $(damping), tol = $(tol)")
lines!(ax, energies, color=:red)


fig2
# Out:
# Consider dt ≈ 0.001786 for this spin configuration at tol = 0.001000. Current value is dt = 0.001785.

# %%
#Sample
kT      = 1.7*Sunny.meV_per_K
damping = 0.1
si=10 # q-space pixel size as 1/si

langevin = Langevin(dt; damping, kT)

# Energy range: max resolvable frequency ~ π/dt, but stay physically reasonable

energies = range(0, 5, 100)

sys_i = reshape_supercell(sys_Ho, [si 0 0; 0 si 0; 0 0 si]) 
randomize_spins!(sys_i)

formfactors = [1 => FormFactor("Ho3")]
sc = SampledCorrelations(sys_i; dt, energies, measure=ssf_perp(sys_i; formfactors))

n_decorr  = nsteps   # steps between samples (matching your thermalization)
n_samples = 50     # more samples = smoother spectrum

@showprogress for sample in 1:n_samples #for sample in 1:n_samples
    for _ in 1:n_decorr
        step!(sys_i, langevin)
    end
    add_sample!(sc, sys_i)
end
# Out:
# [6543] signal 15: Terminated: 15
# in expression starting at /Users/amaliedavidsen/Documents/uni_MSc/Advanced_Magnetism/Ho2Ti2O7_Sunny/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X14sZmlsZQ==.jl:21
# __psynch_cvwait at /usr/lib/system/libsystem_kernel.dylib (unknown line)
# unknown function (ip: 0x0) at (unknown file)
# * at ./int.jl:88 [inlined]
# nextL at ./abstractarray.jl:3085 [inlined]
# _sub2ind_recurse at ./abstractarray.jl:3081 [inlined]
# _sub2ind_recurse at ./abstractarray.jl:3081 [inlined]
# _sub2ind_recurse at ./abstractarray.jl:3081 [inlined]
# _sub2ind_recurse at ./abstractarray.jl:3081 [inlined]
# _sub2ind at ./abstractarray.jl:3065 [inlined]
# _sub2ind at ./abstractarray.jl:3049 [inlined]
# _to_linear_index at ./abstractarray.jl:1377 [inlined]
# getindex at ./array.jl:929 [inlined]
# getindex at ./multidimensional.jl:743 [inlined]
# accum_ewald_grad! at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/System/Ewald.jl:199
# set_energy_grad_dipoles! at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/System/Interactions.jl:538
# #step!#442 at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/Integrators.jl:396
# step! at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/Integrators.jl:379 [inlined]
# #trajectory!#617 at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/SampledCorrelations/CorrelationSampling.jl:26
# trajectory! at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/SampledCorrelations/CorrelationSampling.jl:21
# unknown function (ip: 0x346af4073) at (unknown file)
# new_sample! at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/SampledCorrelations/CorrelationSampling.jl:43
# #add_sample!#619 at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/SampledCorrelations/CorrelationSampling.jl:174 [inlined]
# add_sample! at /Users/amaliedavidsen/.julia/packages/Sunny/BKJXC/src/SampledCorrelations/CorrelationSampling.jl:156
# unknown function (ip: 0x346a1809b) at (unknown file)
# jl_apply at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/./julia.h:2391 [inlined]
# do_call at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/interpreter.c:123
# eval_stmt_value at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/interpreter.c:194
# eval_body at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/interpreter.c:689
# jl_interpret_toplevel_thunk at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/interpreter.c:898
# jl_toplevel_eval_flex at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/toplevel.c:1035
# jl_toplevel_eval_flex at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/toplevel.c:975
# ijl_toplevel_eval at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/toplevel.c:1047 [inlined]
# ijl_toplevel_eval_in at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/toplevel.c:1092
# eval at ./boot.jl:489
# include_string at ./loading.jl:2874
# jl_apply at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/./julia.h:2391 [inlined]
# jl_f_invokelatest at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/builtins.c:881
# #notebook_runcell_request##0 at /Users/amaliedavidsen/.vscode/extensions/julialang.language-julia-1.215.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
# withpath at /Users/amaliedavidsen/.vscode/extensions/julialang.language-julia-1.215.2/scripts/packages/VSCodeServer/src/repl.jl:325
# notebook_runcell_request at /Users/amaliedavidsen/.vscode/extensions/julialang.language-julia-1.215.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
# unknown function (ip: 0x115b141d3) at (unknown file)
# dispatch_msg at /Users/amaliedavidsen/.vscode/extensions/julialang.language-julia-1.215.2/scripts/packages/JSONRPC/src/typed.jl:0
# jfptr_dispatch_msg_10646 at /Users/amaliedavidsen/.julia/compiled/v1.12/VSCodeServer/p62gK_JvAcd.dylib (unknown line)
# #serve_notebook#180 at /Users/amaliedavidsen/.vscode/extensions/julialang.language-julia-1.215.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147
# serve_notebook at /Users/amaliedavidsen/.vscode/extensions/julialang.language-julia-1.215.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:81
# unknown function (ip: 0x115844123) at (unknown file)
# top-level scope at /Users/amaliedavidsen/.vscode/extensions/julialang.language-julia-1.215.2/scripts/notebook/notebook.jl:28
# jl_toplevel_eval_flex at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/toplevel.c:1024
# jl_toplevel_eval_flex at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/toplevel.c:975
# ijl_toplevel_eval at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/toplevel.c:1047 [inlined]
# ijl_toplevel_eval_in at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/toplevel.c:1092
# eval at ./boot.jl:489
# include_string at ./loading.jl:2874
# _include at ./loading.jl:2934
# include at ./Base.jl:306
# exec_options at ./client.jl:317
# _start at ./client.jl:550
# jfptr__start_29115.1 at /Users/amaliedavidsen/.julia/juliaup/julia-1.12.6+0.aarch64.apple.darwin14/Julia-1.12.app/Contents/Resources/julia/lib/julia/sys.dylib (unknown line)
# jl_apply at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/./julia.h:2391 [inlined]
# true_main at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/jlapi.c:971
# jl_repl_entrypoint at /Users/julia/.julia/scratchspaces/a66863c6-20e8-4ff4-8a62-49f30b1f605e/agent-cache/default-honeycrisp-HL2F7YQ3XH.0/build/default-honeycrisp-HL2F7YQ3XH-0/julialang/julia-release-1-dot-12/src/jlapi.c:1139
# unknown function (ip: 0x0) at (unknown file)
# Allocations: 748511074 (Pool: 748508373; Big: 2701); GC: 642

# %%
#Plot (Q,E)-colormap (energies are chosen, q's aren't yet)
fig = Figure(size=(800, 600))
qbs = 0.0


qbs  = 0.0:0.5:1.5
dirs = ["h", "h", "h", "h"]  # adjust per slice
npts = 200

fig = Figure(size=(1200, 900))

for (i, qb) in enumerate(qbs)
    path = [[-4, qb, 0], [4, qb, 0]]
    qpts = q_space_path(crystal, path, npts)
    Sqw  = intensities(sc, qpts; energies=:available, kT)

    xticks, xlabels = qticks_lang(5, path, npts, dirs[i])
    emax = energies[end]

    plot_intensities!(fig[fldmod1(i, 2)...], Sqw;
        title = "K = $qb",
        colormap = :viridis,
        axis = (
            yticks      = 0:emax/emax:emax,
            xticks      = (xticks, xlabels),
            xlabel      = "(H $(qb) 0) (r.l.u.)",
            ylabel      = "Energy (meV)",
        )
    )
end
#Ising-SIA = $(D), 
Label(fig[0, 1:2], "Jnn = $(J), with dipole-dipole \nSystem size: $(si)x$(si)x$(si), tol: $(tol), damping: $(damping), dt: $(dt), T = $(kT/Sunny.meV_per_K) K"; fontsize=15, font=:bold)

fig

# %%
#Plot integrated over all E (Q,Q)-cut (Static intensities)
qpts = q_space_grid(crystal, [1, 1, 0], range(-6, 6, 200), [0, 0, 1], (-6, 6))
Sq  = intensities_static(sc, qpts; kT)

fig = Figure(; size=(700,500))
#Ising-SIA = $(D),
plot_intensities!(fig[1,1], Sq; title="Jnn = $(J), with dipole-dipole \nStatic/integrated 0<E<$(energies[end]) meV \nSystem size: $(si)x$(si)x$(si), tol: $(tol), damping: $(damping), dt: $(dt), T = $(round(kT/Sunny.meV_per_K; digits=3)) K", colormap=:viridis)
ax = current_axis()
ax.aspect = DataAspect()
fig
